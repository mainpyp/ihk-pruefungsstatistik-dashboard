# %%
import pandas as pd
import glob
import os

path_to_year = "../data/xls_data/20234/"

# %%
    
def parse_dataframe(path: str) -> pd.DataFrame:
    
    df = pd.read_html(path)
    # Concatenate all dataframes in the list along the columns axis, using inner join to handle missing data
    parsed_df = pd.concat(df, axis=1, join='inner')
    # Set the column names to the values in the second row
    parsed_df.columns = parsed_df.iloc[1]
    # Drop the first two rows as they are not data
    parsed_df = parsed_df.iloc[2:]
    # Remove the last column as it's not needed
    parsed_df = parsed_df.iloc[:, :-1]
    # Set the column names to the values in the first row
    parsed_df.columns = parsed_df.iloc[0]
    # Drop the first row as it's now redundant
    parsed_df = parsed_df.iloc[1:]
    # Prepend 'Index' to the column names to create a clear index column
    parsed_df.columns = ["Index"] + parsed_df.columns.tolist()[1:]
    # Set 'Index' as the index of the dataframe
    parsed_df.set_index("Index", inplace=True)
    # Transpose the dataframe to change the orientation of the data
    parsed_df = parsed_df.T
    # Rename a column to correct a typo in the name
    parsed_df.rename(columns={"ï¿½ Gesamtpunktzahl": "Gesamtpunktzahl"}, inplace=True)
    # Find the index of a specific column to use as a reference
    last_index = parsed_df.columns.get_loc("Note 6 in Prozent")
    # Extract column names after the reference column to use as modules
    modules = parsed_df.columns.tolist()[last_index + 1:]
    # Select only columns up to and including the reference column
    parsed_df = parsed_df.iloc[:, :last_index+1]
    # Add a new column 'modules' with the same list of modules for each row
    parsed_df["modules"] = [modules] * len(parsed_df)
    # Concatenate the new dataframe to the full dataframe, using 'Standort' as the index
    parsed_df["Standort"] = parsed_df.index
    return parsed_df

# %%
all_berufe = glob.glob(path_to_year + "*")


for path_to_beruf in all_berufe:
    full_df = pd.DataFrame()
    all_standorte_xls = glob.glob(path_to_beruf + "/*.xls")
    
    for path in all_standorte_xls:
        parsed_df = parse_dataframe(path)
        full_df = pd.concat([full_df, parsed_df], ignore_index=True)

    full_df = full_df.drop_duplicates(subset=full_df.columns.difference(['modules']))
    full_df["Standort"] = full_df["Standort"].str.replace("IHK ", "").str.replace("zu", "").str.replace(" ", "").str.replace("für", "")
        
    full_df.set_index("Standort", inplace=True)
    full_df.sort_index(inplace=True)
    full_df = full_df.fillna(0)
    
    # year, beruf_name = path_to_beruf.split("/")[:-2]
    year, beruf_name = path_to_beruf.split("/")[-2:]
    print(f"{year}/{beruf_name}")
    
    output_folder = f"../data/csv_data/{year}/"
    if not os.path.exists(output_folder):
        print(f"Creating folder {output_folder}")
        os.makedirs(output_folder)

    output_path = f"{output_folder}/{beruf_name}.csv"
    full_df.to_csv(output_path)
    print(f"Saved to {output_path}")
# Out:
# 20234/Kaufmann-Kauffrau-im-E-Commerce
# Creating folder ../data/csv_data/20234/
# Saved to ../data/csv_data/20234//Kaufmann-Kauffrau-im-E-Commerce.csv
# 20234/FachinformatikerFachinformatikerin-Fachrichtung:-Digitale-Vernetzung
# Saved to ../data/csv_data/20234//FachinformatikerFachinformatikerin-Fachrichtung:-Digitale-Vernetzung.csv
# 20234/FachinformatikerFachinformatikerin-Fachrichtung:-Anwendungsentwicklung
# Saved to ../data/csv_data/20234//FachinformatikerFachinformatikerin-Fachrichtung:-Anwendungsentwicklung.csv
# 20234/Kaufmann-Kauffrau-für-Büromanagement
# Saved to ../data/csv_data/20234//Kaufmann-Kauffrau-für-Büromanagement.csv
# 20234/FachinformatikerFachinformatikerin-Fachrichtung:-Systemintegration
# Saved to ../data/csv_data/20234//FachinformatikerFachinformatikerin-Fachrichtung:-Systemintegration.csv
# 20234/FachinformatikerFachinformatikerin-Fachrichtung:-Daten-und-Prozessanalyse
# Saved to ../data/csv_data/20234//FachinformatikerFachinformatikerin-Fachrichtung:-Daten-und-Prozessanalyse.csv
# 20234/Kaufmann-Kauffrau-für-Dialogmarketing
# Saved to ../data/csv_data/20234//Kaufmann-Kauffrau-für-Dialogmarketing.csv
# 20234/Kaufmann-Kauffrau-für-Marketingkommunikation
# Saved to ../data/csv_data/20234//Kaufmann-Kauffrau-für-Marketingkommunikation.csv

# %%
# Out:
# Index                         Anzahl Teilnehmer davon bestanden  \
# Standort
# Aachen                                       30              28
# ArnsbergHellweg-Sauerland                     9               9
# Aschaffenburg                                 4               4
# Berlin                                       65              56
# Bodensee-Oberschwaben                         5               5
# ...                                         ...             ...
# Wiesbaden                                     4               3
# Wuppertal-Solingen-Remscheid                 20              17
# Würzburg-Schweinfurt                         25              24
# bundesweit                                 1334            1232
# diePfalzinLudwigshafenamRhein                12              12
#
# Index                         Bestehensquote ø Gesamtpunktzahl Note 1  \
# Standort
# Aachen                                   933                66      0
# ArnsbergHellweg-Sauerland               1000                68      0
# Aschaffenburg                           1000                65      0
# Berlin                                   862                65      0
# Bodensee-Oberschwaben                   1000                75      0
# ...                                      ...               ...    ...
# Wiesbaden                                750                66      0
# Wuppertal-Solingen-Remscheid             850                64      0
# Würzburg-Schweinfurt                     960                70      0
# bundesweit                               924                69     12
# diePfalzinLudwigshafenamRhein           1000                69      0
#
# Index                         Note 1 in Prozent Note 2 Note 2 in Prozent  \
# Standort
# Aachen                                       00      4               133
# ArnsbergHellweg-Sauerland                    00      0                00
# Aschaffenburg                                00      0                00
# Berlin                                       00      9               138
# Bodensee-Oberschwaben                        00      1               200
# ...                                         ...    ...               ...
# Wiesbaden                                    00      1               250
# Wuppertal-Solingen-Remscheid                 00      0                00
# Würzburg-Schweinfurt                         00      5               200
# bundesweit                                   09    215               161
# diePfalzinLudwigshafenamRhein                00      2               167
#
# Index                         Note 3 Note 3 in Prozent Note 4  \
# Standort
# Aachen                            12               400     13
# ArnsbergHellweg-Sauerland          6               667      3
# Aschaffenburg                      2               500      2
# Berlin                            27               415     23
# Bodensee-Oberschwaben              3               600      1
# ...                              ...               ...    ...
# Wiesbaden                          2               500      0
# Wuppertal-Solingen-Remscheid       9               450      9
# Würzburg-Schweinfurt              11               440      8
# bundesweit                       600               450    429
# diePfalzinLudwigshafenamRhein      5               417      5
#
# Index                         Note 4 in Prozent Note 5 Note 5 in Prozent  \
# Standort
# Aachen                                      433      1                33
# ArnsbergHellweg-Sauerland                   333      0                00
# Aschaffenburg                               500      0                00
# Berlin                                      354      4                62
# Bodensee-Oberschwaben                       200      0                00
# ...                                         ...    ...               ...
# Wiesbaden                                    00      1               250
# Wuppertal-Solingen-Remscheid                450      2               100
# Würzburg-Schweinfurt                        320      1                40
# bundesweit                                  322     68                51
# diePfalzinLudwigshafenamRhein               417      0                00
#
# Index                         Note 6 Note 6 in Prozent  \
# Standort
# Aachen                             0                00
# ArnsbergHellweg-Sauerland          0                00
# Aschaffenburg                      0                00
# Berlin                             2                31
# Bodensee-Oberschwaben              0                00
# ...                              ...               ...
# Wiesbaden                          0                00
# Wuppertal-Solingen-Remscheid       0                00
# Würzburg-Schweinfurt               0                00
# bundesweit                        10                07
# diePfalzinLudwigshafenamRhein      0                00
#
# Index                                                                    modules
# Standort
# Aachen                         [Sortimentsbewirtschaftung und Vertragsanbahnu...
# ArnsbergHellweg-Sauerland      [Sortimentsbewirtschaftung und Vertragsanbahnu...
# Aschaffenburg                  [Sortimentsbewirtschaftung und Vertragsanbahnu...
# Berlin                         [Sortimentsbewirtschaftung und Vertragsanbahnu...
# Bodensee-Oberschwaben          [Sortimentsbewirtschaftung und Vertragsanbahnu...
# ...                                                                          ...
# Wiesbaden                      [Sortimentsbewirtschaftung und Vertragsanbahnu...
# Wuppertal-Solingen-Remscheid   [Sortimentsbewirtschaftung und Vertragsanbahnu...
# Würzburg-Schweinfurt           [Sortimentsbewirtschaftung und Vertragsanbahnu...
# bundesweit                     [Sortimentsbewirtschaftung und Vertragsanbahnu...
# diePfalzinLudwigshafenamRhein  [Sortimentsbewirtschaftung und Vertragsanbahnu...
#
# [81 rows x 17 columns]

# %%
# Out:
# Index Anzahl Teilnehmer davon bestanden Bestehensquote ø Gesamtpunktzahl  \
# 0                     4               3            750                66
# 1                  1334            1232            924                69
# 2                     9               9           1000                75
# 3                    21              20            952                69
# 4                     7               6            857                64
# ..                  ...             ...            ...               ...
# 76                    8               8           1000                75
# 77                   12              12           1000                80
# 78                   10              10           1000                70
# 79                   31              31           1000                73
# 80                   17              14            824                65
#
# Index Note 1 Note 1 in Prozent Note 2 Note 2 in Prozent Note 3  \
# 0          0                00      1               250      2
# 1         12                09    215               161    600
# 2          0                00      1               111      7
# 3          0                00      1                48     14
# 4          0                00      1               143      2
# ..       ...               ...    ...               ...    ...
# 76         0                00      3               375      3
# 77         1                83      6               500      4
# 78         1               100      2               200      2
# 79         0                00      8               258     15
# 80         0                00      2               118      6
#
# Index Note 3 in Prozent Note 4 Note 4 in Prozent Note 5 Note 5 in Prozent  \
# 0                   500      0                00      1               250
# 1                   450    429               322     68                51
# 2                   778      1               111      0                00
# 3                   667      5               238      1                48
# 4                   286      3               429      1               143
# ..                  ...    ...               ...    ...               ...
# 76                  375      2               250      0                00
# 77                  333      1                83      0                00
# 78                  200      5               500      0                00
# 79                  484      8               258      0                00
# 80                  353      7               412      2               118
#
# Index Note 6 Note 6 in Prozent  \
# 0          0                00
# 1         10                07
# 2          0                00
# 3          0                00
# 4          0                00
# ..       ...               ...
# 76         0                00
# 77         0                00
# 78         0                00
# 79         0                00
# 80         0                00
#
# Index                                            modules  \
# 0      [Sortimentsbewirtschaftung und Vertragsanbahnu...
# 1      [Sortimentsbewirtschaftung und Vertragsanbahnu...
# 2      [Sortimentsbewirtschaftung und Vertragsanbahnu...
# 3      [Sortimentsbewirtschaftung und Vertragsanbahnu...
# 4      [Sortimentsbewirtschaftung und Vertragsanbahnu...
# ..                                                   ...
# 76     [Sortimentsbewirtschaftung und Vertragsanbahnu...
# 77     [Sortimentsbewirtschaftung und Vertragsanbahnu...
# 78     [Sortimentsbewirtschaftung und Vertragsanbahnu...
# 79     [Sortimentsbewirtschaftung und Vertragsanbahnu...
# 80     [Sortimentsbewirtschaftung und Vertragsanbahnu...
#
# Index                                         Standort
# 0                                            Wiesbaden
# 1                                           bundesweit
# 2                                         Braunschweig
# 3                                             Schwaben
# 4                                               Erfurt
# ..                                                 ...
# 76                                           Flensburg
# 77                                   Heilbronn-Franken
# 78                                         Rheinhessen
# 79                                      Kassel-Marburg
# 80     NiederrheinischeIHKDuisburg-Wesel-KleveDuisburg
#
# [81 rows x 18 columns]
